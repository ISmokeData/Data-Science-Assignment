# %% [markdown]
# Q1.Write a Python function that takes in two arrays of data and calculates the F-value for a variance ratio
# test. The function should return the F-value and the corresponding p-value for the test.
#
# Ans- import numpy as np
# from scipy import stats
#
# def variance_ratio_test(data1, data2):
#     n1 = len(data1)
#     n2 = len(data2)
#
#     var1 = np.var(data1, ddof=1)
#     var2 = np.var(data2, ddof=1)
#
#     F = var1 / var2 if var1 > var2 else var2 / var1
#     df1 = n1 - 1
#     df2 = n2 - 1
#     p_value = 2 * min(stats.f.cdf(F, df1, df2), 1 - stats.f.cdf(F, df1, df2))
#
#     return F, p_value

# %% [markdown]
# Q2. Given a significance level of 0.05 and the degrees of freedom for the numerator and denominator of an
# F-distribution, write a Python function that returns the critical F-value for a two-tailed test.
#
# Ans- from scipy.stats import f
#
# def critical_f(alpha, dfn, dfd):
#     return f.ppf(alpha/2, dfn, dfd, loc=0, scale=1)

# %% [markdown]
# Q3. Write a Python program that generates random samples from two normal distributions with known
# variances and uses an F-test to determine if the variances are equal. The program should output the Fvalue, degrees of freedom, and p-value for the test.
#
# Ans- import numpy as np
# from scipy import stats
#
# **Set the known variances for the two populations**
# var1 = 4
# var2 = 9
#
# **Set the sample sizes for the two populations**
# n1 = 20
# n2 = 25
#
# **Generate random samples from the two normal distributions**
# sample1 = np.random.normal(loc=0, scale=np.sqrt(var1), size=n1)
# sample2 = np.random.normal(loc=0, scale=np.sqrt(var2), size=n2)
#
# **Perform an F-test to determine if the variances are equal**
# F = np.var(sample1, ddof=1) / np.var(sample2, ddof=1) if np.var(sample1, ddof=1) > np.var(sample2, ddof=1) else np.var(sample2, ddof=1) / np.var(sample1, ddof=1)
# dfn = n1 - 1
# dfd = n2 - 1
# p_value = 2 * min(stats.f.cdf(F, dfn, dfd), 1 - stats.f.cdf(F, dfn, dfd))
#
# **Output the results**
# print("F-value:", F)
# print("Degrees of freedom:", dfn, "and", dfd)
# print("p-value:", p_value)

# %% [markdown]
# Q4.The variances of two populations are known to be 10 and 15. A sample of 12 observations is taken from
# each population. Conduct an F-test at the 5% significance level to determine if the variances are
# significantly different.
#
# Ans- A (variance) = 10
#
#     B (variance) = 15
#
#     sample = 12
#
#     s1 = 10/ 12-1 = 0.909
#
#     s2 = 15/12-1 = 1.363
#
#     f =  s1/s2
#
#     f = 0.909/1.363 = 0.666
#
#     Decision Rule
#     df1 = 12 - 1 = 11
#     df2 = 12 - 1 = 11
#
#     significance level = 0.05
#
#     if f is greater than 2.85 than reject the null hypothesis
#
#     0.666 < 2.85, we fail to reject the null hypothesis

# %% [markdown]
# Q8. The following data represent the waiting times in minutes at two different restaurants on a Saturday
# night: Restaurant A: 24, 25, 28, 23, 22, 20, 27; Restaurant B: 31, 33, 35, 30, 32, 36. Conduct an F-test at the 5%
# significance level to determine if the variances are significantly different.
#
# Ans = Restaurant A: 24, 25, 28, 23, 22, 20, 27
#
# Restaurant B: 31, 33, 35, 30, 32, 36
#
# N1 = 7
#
# N2 = 6
#
# Variance of restaurant A = 0.02
#
# variance of restaurant B = 0.02
#
# s1 = Variance of restaurant A/ N1 - 1
# s1 = 0.02 / 6
# s1 = 0.003
#
# s2 = Variance of restaurant B / N2 - 2
# s2 = 0.02/ 5
# s2 = 0.004
#
# f = s1 / s2
# f = 0.003 / 0.004
# f = 0.75
#
# Decision Rule
# df1 = N1 - 1 = 6
# df2 = N2 - 1 = 5
#
# significance level = 0.05
#
# if F test is greater than 3.97, reject the Null Hypothesis
#
# 0.75 < 3.97 , we fail to reject the null hypothesis

# %% [markdown]
# Q9. The following data represent the test scores of two groups of students: Group A: 80, 85, 90, 92, 87, 83;
# Group B: 75, 78, 82, 79, 81, 84. Conduct an F-test at the 1% significance level to determine if the variances
# are significantly different.
#
# Ans- Group A : 80, 85, 90, 92, 87, 83
#
# Group B: 75, 78, 82, 79, 81, 84
#
# N1 = 6
#
# N2 = 6
#
# variance of Group A = 0.04
#
# variance of Group B = 0.02
#
# S1 = 0.04 / 5 = 0.008
#
# s2 = 0.02 / 5 = 0.004
#
# f = 0.008 / 0.004 = 2
#
# df1 = 5
#
# df2 = 5
#
# significance level = 0.01
#
# 2 < 3.45 , we fail to reject the null hypothesis
